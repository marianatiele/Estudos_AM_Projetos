# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaNatiele/AprendizadoMaquina_Projetos/blob/main/Regress%C3%A3o_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Regressão Linear
# 📗 **Fontes**
# </br>1- [LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)</br>
# 2 - [ResidualsPlot](https://www.scikit-yb.org/en/latest/api/regressor/residuals.html)

# %% [markdown]
# ## Regressão Linear Simples

# %%
#Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot

# %%
#DataFrame
dados = pd.read_csv('cars.csv', sep=',')
dados.head()
# Out:
#    Unnamed: 0  speed  dist
# 0           1      4     2
# 1           2      4    10
# 2           3      7     4
# 3           4      7    22
# 4           5      8    16

# %%
dados.shape
# Out:
# (50, 3)

# %%
#Apagando a coluna Unnamed
dados = dados.drop(['Unnamed: 0'], axis=1)
dados.tail()
# Out:
#     speed  dist
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
#definindo o X e Y, sendo X a dist INDEPENDENTE e Y a velocidade DEPENDENTE
x = dados.iloc[:,1].values
y = dados.iloc[:,0].values

x
# Out:
# array([  2,  10,   4,  22,  16,  10,  18,  26,  34,  17,  28,  14,  20,
#         24,  28,  26,  34,  34,  46,  26,  36,  60,  80,  20,  26,  54,
#         32,  40,  32,  40,  50,  42,  56,  76,  84,  36,  46,  68,  32,
#         48,  52,  56,  64,  66,  54,  70,  92,  93, 120,  85])

# %%
#Correlação entre x e y
correlacao = np.corrcoef(x,y)
correlacao
# Out:
# array([[1.       , 0.8068949],
#        [0.8068949, 1.       ]])
